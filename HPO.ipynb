# %%
# !git clone https://github.com/XinyuanLiao/ComplexNDM.git
# Out:
# Cloning into 'ComplexNDM'...
# remote: Enumerating objects: 307, done.
# remote: Counting objects: 100% (188/188), done.
# remote: Compressing objects: 100% (150/150), done.
# remote: Total 307 (delta 94), reused 86 (delta 35), pack-reused 119 (from 1)
# Receiving objects: 100% (307/307), 2.20 MiB | 10.55 MiB/s, done.
# Resolving deltas: 100% (149/149), done.
